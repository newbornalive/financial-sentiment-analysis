# %% [markdown]
# # Financial Sentiment Analysis
#
# This notebook loads labelled financial headlines, runs the deterministic baseline, and evaluates classification performance.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

import pandas as pd
from financial_sentiment.models import RuleBasedAnalyzer
from financial_sentiment.pipeline import run_pipeline
from financial_sentiment.visualization import save_confusion_matrix

# %%
data_path = PROJECT_ROOT / 'data' / 'sample_financial_text.csv'
data = pd.read_csv(data_path)
data.head()

# %%
predictions, metrics = run_pipeline(
    input_path=data_path,
    output_dir=PROJECT_ROOT / 'results',
    analyzer=RuleBasedAnalyzer(),
)
metrics

# %%
pd.crosstab(
    predictions['label'],
    predictions['prediction'],
    rownames=['Actual'],
    colnames=['Predicted'],
)

# %% [markdown]
# ## Next analytical step
#
# Run VADER and FinBERT on the same labelled sample, compare macro-F1 and class-specific recall, and inspect disagreement cases rather than relying on aggregate accuracy alone.
